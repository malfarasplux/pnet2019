# %%
# cd /github/pnet2019/grid_search_loop/Neurons
# GNU/Linux commands
# grep AUC /github/pnet2019/grid_search_loop/Neurons/*/rep*

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# with open('AUCtr5000.txt') as f:
#     lineList = f.readlines()

# %%
with open('/github/pnet2019/grid_search_loop/Neurons/N_AUCtr5000.txt') as f:
    lineList = f.readlines()

# %%
len(lineList)
# Out:
# 1014

# %%
val_dict = {}
list1000 = []

for i, line in enumerate(lineList):      
    N_i, scale_i, mem_i, AUC_i = line.split('_')[1],line.split('_')[2], line.split('_')[3], float(line.split(':')[1][:-1])         
#     print ("line {0} = {1}".format(i, lineval)) 
    if N_i not in val_dict.keys():
        val_dict[N_i] = []     
    val_dict[N_i].append(AUC_i)
    print (N_i)
# Out:
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# ...

# %%
lineList[0].split(':')[1][:-1]
# Out:
# '0.6755'

# %%
val_dict.keys()
# Out:
# dict_keys(['1000', '200', '500', '050', '075', '800'])

# %%
len(val_dict['050'])
# Out:
# 169

# %%
p50 = [np.mean(val_dict['050']), np.std(val_dict['050']), len(val_dict['050'])]

# %%
p75 = [np.mean(val_dict['075']), np.std(val_dict['075']), len(val_dict['075'])]

# %%
# p100 = [np.mean(val_dict['100']), np.std(val_dict['100']), len(val_dict['100'])]

# %%
p200 = [np.mean(val_dict['200']), np.std(val_dict['200']), len(val_dict['200'])]

# %%
p500 = [np.mean(val_dict['500']), np.std(val_dict['500']), len(val_dict['500'])]

# %%
p800 = [np.mean(val_dict['800']), np.std(val_dict['800']), len(val_dict['800'])]

# %%
p1000 = [np.mean(val_dict['1000']), np.std(val_dict['1000']), len(val_dict['1000'])]

# %%
a = list(val_dict.keys())
a.sort()
print(a)
# Out:
# ['050', '075', '1000', '200', '500', '800']

# %%
p = np.vstack([p50, p75, p200, p500, p800, p1000])
Nval = [50, 75, 200, 500, 800, 1000]

# %%
# N dependece plot
fig, ax = plt.subplots()
im = plt.errorbar(Nval, p[:,0], yerr = p[:,1], marker = 'x', ecolor = 'k', capsize = 3, linewidth = 2, color = 'r')
ax.set_title('AUC-Neuron dependence')
ax.set_xlabel('N')
ax.set_ylabel('AUC')
ax.set_xlim([0,1100])
# ax.set_ylim([0.6,0.9])
ax.grid()
fig.savefig("test.svg", format="svg")

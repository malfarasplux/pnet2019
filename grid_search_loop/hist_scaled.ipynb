# %%
# %matplotlib notebook
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
Y = np.loadtxt('tr5000_N800/printY/Y_800_0.001_1.800.txt')
target = np.loadtxt('tr5000_N800/printY/T_800_0.001_1.800.txt')

# %%
th_min = -3.1972
th_scale = 5.6622

# %%
np.max(Y)
# Out:
# 2.465098121860388

# %%
sep_idx = np.where(target==1)[0]
healthy_idx = np.where(target==0)[0]

# %%
Y_sep_800 = (Y[sep_idx] - th_min)/th_scale
Y_healthy_800 = (Y[healthy_idx] - th_min)/th_scale

# %%
plt.figure()
plt.hist(Y_sep_800, bins=500, color='red', alpha=0.5);
plt.hist(Y_healthy_800, bins=500, color='blue', alpha=0.5);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Y = np.loadtxt('tr5000_N100/printY/Y_100_0.001_1.800.txt')
target = np.loadtxt('tr5000_N100/printY/T_100_0.001_1.800.txt')

# %%
sep_idx = np.where(target==1)[0]
healthy_idx = np.where(target==0)[0]

# %%
th_min = -0.5720
th_scale = 1.1528

# %%
Y_sep = (Y[sep_idx] - th_min)/th_scale
Y_healthy = (Y[healthy_idx] - th_min)/th_scale

# %%
plt.hist(Y_sep, bins=500, color='red', alpha=0.5);
plt.hist(Y_healthy, bins=500, color='blue', alpha=0.5);

# %%
plt.figure()
plt.hist(Y_sep, bins=500, color='red', alpha=0.5);
plt.hist(Y_healthy, bins=500, color='blue', alpha=0.5);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.max(Y_healthy_800)

# %%
np.max(Y_healthy)

# %% [markdown]
# # Exploration of a single ICU sepsis data log

# %%
# Imports
import pandas

# %%
path = '../training/'

# %%
# Choose patient sample
sample_num = 1

# %%
# Import and print dataframe layout
def loadICUdata(sample_num, path = './', printdf = False):
    samplestr = 'p' + (str(sample_num) + '.psv').rjust(9, '0')
    fname = path + samplestr
    df = pandas.read_csv(fname, sep = '|')
    print(fname, ' file:')
    if printdf:
        print(df)
    return df

# %%
df = loadICUdata(sample_num, path, True)
# Out:
# ../training/p00001.psv  file:
#        HR  O2Sat  Temp    SBP   MAP   DBP  Resp  EtCO2  BaseExcess  HCO3  \
# 0     NaN    NaN   NaN    NaN   NaN   NaN   NaN    NaN         NaN   NaN
# 1    93.0   92.5   NaN  110.0  76.0  56.0  22.0    NaN         NaN   NaN
# 2    91.0   96.0   NaN  108.0  84.5  72.0  23.5    NaN         NaN   NaN
# 3    93.0   98.0   NaN  123.0  87.0  61.0  21.0    NaN         NaN   NaN
# 4    93.0   95.0   NaN  110.0  81.0  70.0  20.0    NaN         NaN   NaN
# 5     NaN    NaN   NaN    NaN   NaN   NaN   NaN    NaN         NaN   NaN
# 6    91.5   97.0  36.5  104.0  75.0  60.0  20.0    NaN         NaN   NaN
# 7    94.0   95.0   NaN  114.0  85.0  66.0  20.0    NaN         NaN   NaN
# 8    94.0   95.0   NaN  121.0  88.0  69.0  20.0    NaN         NaN   NaN
# 9   102.0   95.0   NaN  117.0  89.0  70.0  20.0    NaN         NaN   NaN
# 10  106.0   97.0  36.8  107.0  82.0  68.0  20.0    NaN         NaN   NaN
# 11  107.0   95.0   NaN  112.0  86.0  67.0  20.0    NaN         NaN   NaN
# 12  102.0   95.0   NaN  108.0  80.0  59.0  20.0    NaN         NaN   NaN
# 13   98.0   95.0   NaN  112.0  81.0  61.0  20.0    NaN         NaN   NaN
# 14   95.0   96.0  36.6  110.0  82.0  61.0  20.0    NaN         NaN   NaN
# 15  105.0   94.0   NaN  119.0  86.0  63.0  22.0    NaN         NaN   NaN
# 16   94.0   93.0   NaN  114.0  84.0  63.0  16.0    NaN         NaN   NaN
# 17   98.0   97.0   NaN  116.0  84.0  63.0  22.0    NaN         NaN   NaN
# 18   98.0   99.0  36.9  121.0  86.0  62.0  18.0    NaN         NaN   NaN
# 19  105.0   95.0   NaN  106.0  76.0  55.0  18.0    NaN         NaN   NaN
# 20   96.0   93.0   NaN  110.0  81.0  62.0  16.0    NaN         NaN   NaN
# 21  102.0   96.0   NaN  115.0  85.0  67.0  18.0    NaN         NaN   NaN
# 22  105.0   97.0  37.0  108.0  83.0  69.0  16.0    NaN         NaN   NaN
# 23  107.0   92.0   NaN  116.0  87.0  70.0  16.0    NaN         NaN   NaN
#
#        ...        WBC  Fibrinogen  Platelets  Age  Gender  Unit1  Unit2  \
# 0      ...        NaN         NaN        NaN   73       1      1      0
# 1      ...        NaN         NaN        NaN   73       1      1      0
# 2      ...        NaN         NaN        NaN   73       1      1      0
# 3      ...        NaN         NaN        NaN   73       1      1      0
# 4      ...        NaN         NaN        NaN   73       1      1      0
# 5      ...        NaN         NaN        NaN   73       1      1      0
# 6      ...        NaN         NaN        NaN   73       1      1      0
# 7      ...        NaN         NaN        NaN   73       1      1      0
# 8      ...        NaN         NaN        NaN   73       1      1      0
# 9      ...        NaN         NaN        NaN   73       1      1      0
# 10     ...        NaN         NaN        NaN   73       1      1      0
# 11     ...        NaN         NaN        NaN   73       1      1      0
# 12     ...       10.8         NaN      170.0   73       1      1      0
# 13     ...        NaN         NaN        NaN   73       1      1      0
# 14     ...        NaN         NaN        NaN   73       1      1      0
# 15     ...        NaN         NaN        NaN   73       1      1      0
# 16     ...        NaN         NaN        NaN   73       1      1      0
# 17     ...        NaN         NaN        NaN   73       1      1      0
# 18     ...        NaN         NaN        NaN   73       1      1      0
# 19     ...        NaN         NaN        NaN   73       1      1      0
# 20     ...        NaN         NaN        NaN   73       1      1      0
# 21     ...        NaN         NaN        NaN   73       1      1      0
# 22     ...        NaN         NaN        NaN   73       1      1      0
# 23     ...        NaN         NaN        NaN   73       1      1      0
#
#     HospAdmTime  ICULOS  SepsisLabel
# 0       -214.64       1            0
# 1       -214.64       2            0
# 2       -214.64       3            0
# 3       -214.64       4            0
# 4       -214.64       5            0
# 5       -214.64       6            0
# 6       -214.64       7            0
# 7       -214.64       8            0
# 8       -214.64       9            0
# 9       -214.64      10            0
# 10      -214.64      11            0
# 11      -214.64      12            0
# 12      -214.64      13            0
# 13      -214.64      14            0
# 14      -214.64      15            0
# 15      -214.64      16            0
# 16      -214.64      17            0
# 17      -214.64      18            0
# 18      -214.64      19            0
# 19      -214.64      20            0
# 20      -214.64      21            0
# 21      -214.64      22            0
# 22      -214.64      23            0
# 23      -214.64      24            0
#
# [24 rows x 41 columns]

# %%
df
# Out:
#        HR  O2Sat  Temp    SBP   MAP   DBP  Resp  EtCO2  BaseExcess  HCO3  \
# 0     NaN    NaN   NaN    NaN   NaN   NaN   NaN    NaN         NaN   NaN
# 1    93.0   92.5   NaN  110.0  76.0  56.0  22.0    NaN         NaN   NaN
# 2    91.0   96.0   NaN  108.0  84.5  72.0  23.5    NaN         NaN   NaN
# 3    93.0   98.0   NaN  123.0  87.0  61.0  21.0    NaN         NaN   NaN
# 4    93.0   95.0   NaN  110.0  81.0  70.0  20.0    NaN         NaN   NaN
# 5     NaN    NaN   NaN    NaN   NaN   NaN   NaN    NaN         NaN   NaN
# 6    91.5   97.0  36.5  104.0  75.0  60.0  20.0    NaN         NaN   NaN
# 7    94.0   95.0   NaN  114.0  85.0  66.0  20.0    NaN         NaN   NaN
# 8    94.0   95.0   NaN  121.0  88.0  69.0  20.0    NaN         NaN   NaN
# 9   102.0   95.0   NaN  117.0  89.0  70.0  20.0    NaN         NaN   NaN
# 10  106.0   97.0  36.8  107.0  82.0  68.0  20.0    NaN         NaN   NaN
# 11  107.0   95.0   NaN  112.0  86.0  67.0  20.0    NaN         NaN   NaN
# 12  102.0   95.0   NaN  108.0  80.0  59.0  20.0    NaN         NaN   NaN
# 13   98.0   95.0   NaN  112.0  81.0  61.0  20.0    NaN         NaN   NaN
# 14   95.0   96.0  36.6  110.0  82.0  61.0  20.0    NaN         NaN   NaN
# 15  105.0   94.0   NaN  119.0  86.0  63.0  22.0    NaN         NaN   NaN
# 16   94.0   93.0   NaN  114.0  84.0  63.0  16.0    NaN         NaN   NaN
# 17   98.0   97.0   NaN  116.0  84.0  63.0  22.0    NaN         NaN   NaN
# 18   98.0   99.0  36.9  121.0  86.0  62.0  18.0    NaN         NaN   NaN
# 19  105.0   95.0   NaN  106.0  76.0  55.0  18.0    NaN         NaN   NaN
# 20   96.0   93.0   NaN  110.0  81.0  62.0  16.0    NaN         NaN   NaN
# 21  102.0   96.0   NaN  115.0  85.0  67.0  18.0    NaN         NaN   NaN
# 22  105.0   97.0  37.0  108.0  83.0  69.0  16.0    NaN         NaN   NaN
# 23  107.0   92.0   NaN  116.0  87.0  70.0  16.0    NaN         NaN   NaN
#
#        ...        WBC  Fibrinogen  Platelets  Age  Gender  Unit1  Unit2  \
# 0      ...        NaN         NaN        NaN   73       1      1      0
# 1      ...        NaN         NaN        NaN   73       1      1      0
# 2      ...        NaN         NaN        NaN   73       1      1      0
# 3      ...        NaN         NaN        NaN   73       1      1      0
# 4      ...        NaN         NaN        NaN   73       1      1      0
# 5      ...        NaN         NaN        NaN   73       1      1      0
# 6      ...        NaN         NaN        NaN   73       1      1      0
# 7      ...        NaN         NaN        NaN   73       1      1      0
# 8      ...        NaN         NaN        NaN   73       1      1      0
# 9      ...        NaN         NaN        NaN   73       1      1      0
# 10     ...        NaN         NaN        NaN   73       1      1      0
# 11     ...        NaN         NaN        NaN   73       1      1      0
# 12     ...       10.8         NaN      170.0   73       1      1      0
# 13     ...        NaN         NaN        NaN   73       1      1      0
# 14     ...        NaN         NaN        NaN   73       1      1      0
# 15     ...        NaN         NaN        NaN   73       1      1      0
# 16     ...        NaN         NaN        NaN   73       1      1      0
# 17     ...        NaN         NaN        NaN   73       1      1      0
# 18     ...        NaN         NaN        NaN   73       1      1      0
# 19     ...        NaN         NaN        NaN   73       1      1      0
# 20     ...        NaN         NaN        NaN   73       1      1      0
# 21     ...        NaN         NaN        NaN   73       1      1      0
# 22     ...        NaN         NaN        NaN   73       1      1      0
# 23     ...        NaN         NaN        NaN   73       1      1      0
#
#     HospAdmTime  ICULOS  SepsisLabel
# 0       -214.64       1            0
# 1       -214.64       2            0
# 2       -214.64       3            0
# 3       -214.64       4            0
# 4       -214.64       5            0
# 5       -214.64       6            0
# 6       -214.64       7            0
# 7       -214.64       8            0
# 8       -214.64       9            0
# 9       -214.64      10            0
# 10      -214.64      11            0
# 11      -214.64      12            0
# 12      -214.64      13            0
# 13      -214.64      14            0
# 14      -214.64      15            0
# 15      -214.64      16            0
# 16      -214.64      17            0
# 17      -214.64      18            0
# 18      -214.64      19            0
# 19      -214.64      20            0
# 20      -214.64      21            0
# 21      -214.64      22            0
# 22      -214.64      23            0
# 23      -214.64      24            0
#
# [24 rows x 41 columns]

# %%
# get the sepsis label value
def get_sepsislabel(df):
    sl = df[["SepsisLabel"]]
    count = df['SepsisLabel'].value_counts()
    count_healthy = -1
    count_sep = -1
    
    # An assumption is made that NO sepsis-only records [1,1,1,1,1...] are present --> check 55
    if len(count) == 2:
        count_sep = count[1]
    elif len(count) == 1:
        if sl.values[0] == 0:
            count_healthy = count.values[0]
        elif sl.values[0] == 1:
            count_sep = count.values[0]
    return sl, count_healthy, count_sep

# %%
count = df['SepsisLabel'].value_counts()
count.values
len(count)
sl, ch, cs = get_sepsislabel(df)
len(sl)
# Out:
# 24

# %%
# Print result
SL, ch, cs = get_sepsislabel(df) 
print(ch, cs, cs/len(sl))
# Out:
# 24 -1 -0.041666666666666664

# %% [markdown]
# # Loop study

# %%
# Run in a loop and get a sepsis presence report
SL = []
CH = []
CS = []
CSCH = []
for i in range(1,100):
    df = loadICUdata(i, path, False)
    sl, ch, cs = get_sepsislabel(df) 
    SL.append(sl)
    CH.append(ch)
    CS.append(cs)
    if cs and ch != -1:
        csch = cs/(cs + ch)
    elif cs == -1:
        csch = 0
    elif ch == -1:
        csch = 1
    CSCH.append(csch)
# Out:
# ../training/p00001.psv  file:
# ../training/p00002.psv  file:
# ../training/p00003.psv  file:
# ../training/p00004.psv  file:
# ../training/p00005.psv  file:
# ../training/p00006.psv  file:
# ../training/p00007.psv  file:
# ../training/p00008.psv  file:
# ../training/p00009.psv  file:
# ../training/p00010.psv  file:
# ../training/p00011.psv  file:
# ../training/p00012.psv  file:
# ../training/p00013.psv  file:
# ../training/p00014.psv  file:
# ../training/p00015.psv  file:
# ../training/p00016.psv  file:
# ../training/p00017.psv  file:
# ../training/p00018.psv  file:
# ../training/p00019.psv  file:
# ../training/p00020.psv  file:
# ../training/p00021.psv  file:
# ../training/p00022.psv  file:
# ../training/p00023.psv  file:
# ../training/p00024.psv  file:
# ../training/p00025.psv  file:
# ../training/p00026.psv  file:
# ../training/p00027.psv  file:
# ../training/p00028.psv  file:
# ../training/p00029.psv  file:
# ../training/p00030.psv  file:
# ../training/p00031.psv  file:
# ../training/p00032.psv  file:
# ../training/p00033.psv  file:
# ../training/p00034.psv  file:
# ../training/p00035.psv  file:
# ../training/p00036.psv  file:
# ../training/p00037.psv  file:
# ../training/p00038.psv  file:
# ../training/p00039.psv  file:
# ../training/p00040.psv  file:
# ../training/p00041.psv  file:
# ../training/p00042.psv  file:
# ../training/p00043.psv  file:
# ../training/p00044.psv  file:
# ../training/p00045.psv  file:
# ../training/p00046.psv  file:
# ../training/p00047.psv  file:
# ../training/p00048.psv  file:
# ../training/p00049.psv  file:
# ../training/p00050.psv  file:
# ../training/p00051.psv  file:
# ../training/p00052.psv  file:
# ../training/p00053.psv  file:
# ../training/p00054.psv  file:
# ../training/p00055.psv  file:
# ../training/p00056.psv  file:
# ../training/p00057.psv  file:
# ../training/p00058.psv  file:
# ../training/p00059.psv  file:
# ../training/p00060.psv  file:
# ../training/p00061.psv  file:
# ../training/p00062.psv  file:
# ../training/p00063.psv  file:
# ../training/p00064.psv  file:
# ../training/p00065.psv  file:
# ../training/p00066.psv  file:
# ../training/p00067.psv  file:
# ../training/p00068.psv  file:
# ../training/p00069.psv  file:
# ../training/p00070.psv  file:
# ../training/p00071.psv  file:
# ../training/p00072.psv  file:
# ../training/p00073.psv  file:
# ../training/p00074.psv  file:
# ../training/p00075.psv  file:
# ../training/p00076.psv  file:
# ../training/p00077.psv  file:
# ../training/p00078.psv  file:
# ../training/p00079.psv  file:
# ../training/p00080.psv  file:
# ../training/p00081.psv  file:
# ../training/p00082.psv  file:
# ../training/p00083.psv  file:
# ../training/p00084.psv  file:
# ../training/p00085.psv  file:
# ../training/p00086.psv  file:
# ../training/p00087.psv  file:
# ../training/p00088.psv  file:
# ../training/p00089.psv  file:
# ../training/p00090.psv  file:
# ../training/p00091.psv  file:
# ../training/p00092.psv  file:
# ../training/p00093.psv  file:
# ../training/p00094.psv  file:
# ../training/p00095.psv  file:
# ../training/p00096.psv  file:
# ../training/p00097.psv  file:
# ../training/p00098.psv  file:
# ../training/p00099.psv  file:

# %%
print(CSCH)
# Out:
# [-0.043478260869565216, -0.041666666666666664, -0.023809523809523808, -0.017241379310344827, -0.019607843137254902, -0.021739130434782608, -0.027777777777777776, -0.020408163265306121, -0.034482758620689655, -0.066666666666666666, -0.020408163265306121, -0.023809523809523808, 1, -0.023809523809523808, -0.066666666666666666, 1, -0.050000000000000003, -0.023809523809523808, -0.022222222222222223, -0.024390243902439025, -0.027027027027027029, -0.020408163265306121, -0.02564102564102564, -0.052631578947368418, -0.021739130434782608, -0.083333333333333329, -0.052631578947368418, -0.041666666666666664, -0.022222222222222223, -0.020408163265306121, -0.027777777777777776, -0.037037037037037035, -0.050000000000000003, -0.045454545454545456, -0.020408163265306121, -0.027027027027027029, -0.027777777777777776, -0.033333333333333333, -0.021739130434782608, -0.050000000000000003, -0.025000000000000001, -0.033333333333333333, -0.043478260869565216, -0.052631578947368418, -0.026315789473684209, -0.017241379310344827, 1, -0.024390243902439025, 1, -0.022222222222222223, -0.041666666666666664, -0.045454545454545456, -0.043478260869565216, -0.029411764705882353, 1, -0.019230769230769232, -0.017241379310344827, -0.030303030303030304, -0.052631578947368418, -0.034482758620689655, -0.019607843137254902, -0.040000000000000001, -0.018181818181818181, -0.027027027027027029, -0.045454545454545456, -0.055555555555555552, -0.066666666666666666, 1, -0.02564102564102564, -0.0625, -0.023809523809523808, 1, 1, -0.050000000000000003, -0.023255813953488372, -0.125, -0.043478260869565216, -0.028571428571428571, -0.047619047619047616, -0.041666666666666664, -0.018181818181818181, -0.018518518518518517, -0.050000000000000003, -0.047619047619047616, -0.026315789473684209, -0.025000000000000001, -0.02564102564102564, 1, -0.023255813953488372, -0.058823529411764705, -0.028571428571428571, -0.071428571428571425, -0.02, -0.020833333333333332, -0.02564102564102564, -0.028571428571428571, -0.058823529411764705, -0.041666666666666664, -0.026315789473684209]
